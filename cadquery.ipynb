# %%
import cadquery as cq
from jupyter_cadquery.viewer.client import show, show_object



x = cq.Workplane('XY').box(1,2,3).toSvg()
show_object(x)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[6], line 7
#       2 from jupyter_cadquery.viewer.client import show, show_object
#       6 x = cq.Workplane('XY').box(1,2,3).toSvg()
# ----> 7 show_object(x)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/jupyter_cadquery/viewer/client.py:215, in show_object(obj, name, options, clear, **kwargs)
#     212 OBJECTS["colors"].append(color)
#     213 OBJECTS["alphas"].append(alpha)
# --> 215 show(*OBJECTS["objs"], names=OBJECTS["names"], colors=OBJECTS["colors"], alphas=OBJECTS["alphas"], **kwargs)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/jupyter_cadquery/viewer/client.py:187, in show(names, colors, alphas, *cad_objs, **kwargs)
#     146 def show(*cad_objs, names=None, colors=None, alphas=None, **kwargs):
#     147     """Show CAD objects in Jupyter
#     148
#     149     Valid keywords:
# ...
